# %%
import gymnasium as gym

from stable_baselines3 import A2C

env = gym.make("CartPole-v1", render_mode="rgb_array")

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
    # VecEnv resets automatically
    # if done:
    #   obs = vec_env.reset()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 41.1       |
# |    ep_rew_mean        | 41.1       |
# | time/                 |            |
# |    fps                | 635        |
# |    iterations         | 100        |
# |    time_elapsed       | 0          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -0.621     |
# |    explained_variance | 0.03634143 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 1.25       |
# |    value_loss         | 8.25       |
# --------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 51.5          |
# |    ep_rew_mean        | 51.5          |
# | time/                 |               |
# |    fps                | 622           |
# |    iterations         | 200           |
# |    time_elapsed       | 1             |
# |    total_timesteps    | 1000          |
# | train/                |               |
# |    entropy_loss       | -0.612        |
# |    explained_variance | -0.0018590689 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 199           |
# |    policy_loss        | 1.32          |
# |    value_loss         | 7.02          |
# -----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 57.9         |
# |    ep_rew_mean        | 57.9         |
# | time/                 |              |
# |    fps                | 616          |
# |    iterations         | 300          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -0.608       |
# |    explained_variance | 0.0008621216 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | 1.42         |
# |    value_loss         | 6.07         |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 68.4         |
# |    ep_rew_mean        | 68.4         |
# | time/                 |              |
# |    fps                | 633          |
# |    iterations         | 400          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -0.614       |
# |    explained_variance | -0.001096487 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 1.13         |
# |    value_loss         | 5.31         |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 80.4         |
# |    ep_rew_mean        | 80.4         |
# | time/                 |              |
# |    fps                | 635          |
# |    iterations         | 500          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 2500         |
# | train/                |              |
# |    entropy_loss       | -0.521       |
# |    explained_variance | 0.0043013096 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 499          |
# |    policy_loss        | -16.4        |
# |    value_loss         | 607          |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 87.3         |
# |    ep_rew_mean        | 87.3         |
# | time/                 |              |
# |    fps                | 644          |
# |    iterations         | 600          |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -0.462       |
# |    explained_variance | 0.0021607876 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | 1.09         |
# |    value_loss         | 4.1          |
# ----------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 91.9          |
# |    ep_rew_mean        | 91.9          |
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 700           |
# |    time_elapsed       | 5             |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -0.47         |
# |    explained_variance | -0.0004580021 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | -9.4          |
# |    value_loss         | 672           |
# -----------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 96.9           |
# |    ep_rew_mean        | 96.9           |
# | time/                 |                |
# |    fps                | 652            |
# |    iterations         | 800            |
# |    time_elapsed       | 6              |
# |    total_timesteps    | 4000           |
# | train/                |                |
# |    entropy_loss       | -0.502         |
# |    explained_variance | -0.00012755394 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 799            |
# |    policy_loss        | 0.833          |
# |    value_loss         | 3.04           |
# ------------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 101            |
# |    ep_rew_mean        | 101            |
# | time/                 |                |
# |    fps                | 654            |
# |    iterations         | 900            |
# |    time_elapsed       | 6              |
# |    total_timesteps    | 4500           |
# | train/                |                |
# |    entropy_loss       | -0.478         |
# |    explained_variance | -1.1920929e-07 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 899            |
# |    policy_loss        | 0.515          |
# |    value_loss         | 2.57           |
# ------------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 105          |
# |    ep_rew_mean        | 105          |
# | time/                 |              |
# |    fps                | 657          |
# |    iterations         | 1000         |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -0.475       |
# |    explained_variance | 3.504753e-05 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 0.799        |
# |    value_loss         | 2.13         |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 112          |
# |    ep_rew_mean        | 112          |
# | time/                 |              |
# |    fps                | 658          |
# |    iterations         | 1100         |
# |    time_elapsed       | 8            |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -0.476       |
# |    explained_variance | 7.510185e-05 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | 0.265        |
# |    value_loss         | 1.73         |
# ----------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 115           |
# |    ep_rew_mean        | 115           |
# | time/                 |               |
# |    fps                | 658           |
# |    iterations         | 1200          |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -0.496        |
# |    explained_variance | 0.00033307076 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1199          |
# |    policy_loss        | 0.317         |
# |    value_loss         | 1.38          |
# -----------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 117            |
# |    ep_rew_mean        | 117            |
# | time/                 |                |
# |    fps                | 656            |
# |    iterations         | 1300           |
# |    time_elapsed       | 9              |
# |    total_timesteps    | 6500           |
# | train/                |                |
# |    entropy_loss       | -0.376         |
# |    explained_variance | -0.00015687943 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1299           |
# |    policy_loss        | 0.199          |
# |    value_loss         | 1.08           |
# ------------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 118            |
# |    ep_rew_mean        | 118            |
# | time/                 |                |
# |    fps                | 656            |
# |    iterations         | 1400           |
# |    time_elapsed       | 10             |
# |    total_timesteps    | 7000           |
# | train/                |                |
# |    entropy_loss       | -0.28          |
# |    explained_variance | -3.3974648e-05 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1399           |
# |    policy_loss        | 0.0664         |
# |    value_loss         | 0.812          |
# ------------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 118           |
# |    ep_rew_mean        | 118           |
# | time/                 |               |
# |    fps                | 658           |
# |    iterations         | 1500          |
# |    time_elapsed       | 11            |
# |    total_timesteps    | 7500          |
# | train/                |               |
# |    entropy_loss       | -0.358        |
# |    explained_variance | -6.687641e-05 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1499          |
# |    policy_loss        | 0.343         |
# |    value_loss         | 0.583         |
# -----------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 114           |
# |    ep_rew_mean        | 114           |
# | time/                 |               |
# |    fps                | 660           |
# |    iterations         | 1600          |
# |    time_elapsed       | 12            |
# |    total_timesteps    | 8000          |
# | train/                |               |
# |    entropy_loss       | -0.195        |
# |    explained_variance | -4.851818e-05 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1599          |
# |    policy_loss        | 0.0321        |
# |    value_loss         | 0.402         |
# -----------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 108      |
# |    ep_rew_mean        | 108      |
# | time/                 |          |
# |    fps                | 660      |
# |    iterations         | 1700     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.261   |
# |    explained_variance | 0.0      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.128    |
# |    value_loss         | 0.259    |
# ------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 106           |
# |    ep_rew_mean        | 106           |
# | time/                 |               |
# |    fps                | 661           |
# |    iterations         | 1800          |
# |    time_elapsed       | 13            |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -0.311        |
# |    explained_variance | -4.053116e-05 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1799          |
# |    policy_loss        | 0.0612        |
# |    value_loss         | 0.145         |
# -----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 103          |
# |    ep_rew_mean        | 103          |
# | time/                 |              |
# |    fps                | 661          |
# |    iterations         | 1900         |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -0.282       |
# |    explained_variance | -1.66893e-06 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | 0.0705       |
# |    value_loss         | 0.0639       |
# ----------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 99.5           |
# |    ep_rew_mean        | 99.5           |
# | time/                 |                |
# |    fps                | 661            |
# |    iterations         | 2000           |
# |    time_elapsed       | 15             |
# |    total_timesteps    | 10000          |
# | train/                |                |
# |    entropy_loss       | -0.149         |
# |    explained_variance | -1.9073486e-06 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1999           |
# |    policy_loss        | -0.0024        |
# |    value_loss         | 1.81e+03       |
# ------------------------------------------
# QFontDatabase: Cannot find font directory /home/victor/.pyenv/versions/geodata_venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/victor/.pyenv/versions/geodata_venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/victor/.pyenv/versions/geodata_venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/victor/.pyenv/versions/geodata_venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/victor/.pyenv/versions/geodata_venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
